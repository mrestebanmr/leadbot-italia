# %%
import sys
sys.path.append("..")

from src.scraper import search_businesses
from src.cleaner import limpiar_datos

resultado = search_businesses("agenzie marketing Milano")
print(f"Empresas encontradas: {len(resultado)}")
# Out:
# Empresas encontradas: 20

# %%
from src.cleaner import limpiar_datos

df_limpio = limpiar_datos(resultado)
df_limpio
# Out:
#                                                nombre  ... total_reseñas
# 0                                      Bob and Claire  ...            46
# 1                                           Instasamy  ...            11
# 2   Officine Venticinque | Marketing e comunicazio...  ...             4
# 3                                        Oniro Agency  ...            36
# 4   Beatrice Amerighi | Digital Fashion Strategist...  ...            12
# 5                   226Lab | Agenzia Marketing Milano  ...            52
# 6                                             Parklab  ...            13
# 7                                      Nextre Digital  ...            26
# 8                   Artmouse agenzia di comunicazione  ...            77
# 9                             FB Communication Agency  ...           133
# 10            Agenzia di Marketing Milano • Ad Sphera  ...            33
# 11       Personal Branding | Agenzia Stand Out Milano  ...            34
# ...
